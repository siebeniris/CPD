# %%
cluster_ids = 'cluster_ids_renovated.json'
names = 'renovation_hotel_names.json'

# %%
import json

# %%
with open(cluster_ids) as file:
    clusters = json.load(file)
    
with open(names) as file:
    names= json.load(file)

# %%
['']

# %%
for c in clusters:
    if c['distance']<0.96:
        print(c['searched'], ',' ,c['found'])
# Out:
# Welk Resorts Palm Springs , Welk Resort Palm Springs - Desert Oasis
# Apollo Hotel Amsterdam, a Tribute Portfolio Hotel , Apollo Hotel Amsterdam
# Spa Hotel Mizpe Hayamim , Hotel Spa Mizpe Hayamim
# Nautilus by Arlo , Nautilus
# Steigenberger Golf & Spa Resort Camp de Mar , Steigenberger Golf Resort El Gouna
# The Ritz-Carlton Spa, South Beach , The Ritz-Carlton South Beach
# BEI Hotel San Francisco , Hotel San Francisco
# The Inn at Saratoga, Tapestry Collection by Hilton  , The Burgundy Hotel, Tapestry Collection by Hilton
# Marriott Albuquerque , Marriott Albuquerque Pyramid North
# The Grand Hotel Birmingham , The Birmingham Hotel
# The Savoy Hotel, Miami Beach , The Savoy Hotel - South Beach
# Kimpton Rouge Hotel , Kimpton Rouge
# Chateau Elan Winery & Resort , Chateau Elan Winery Spa and Golf Resort Hotel Braselton
# DoubleTree by Hilton Chicago Midway Airport , DoubleTree by Hilton Chicago-Alsip
# The Westin New Orleans , The Westin New Orleans Canal Place
# ...
